# %% [markdown]
# ##1 Analisis Dataset
#
# Pada data diatas yang ingin  di uji yaitu 5 data.
# untuk mengklasifikasikan dimana K=5
# dengan menggunakan Eunclidean Distance dimana data dibaca yang sekiranya data nya terdekat
# ![Screenshot 2026-04-22 084231.png](data:image/png;base64,...)

# %% [markdown]
# ##2 Pemrosesan Data
# menggunkan pemroresan
# menggunakan Missing Value
# Data yang kosong diisi menggunakan nilai rata-rata (mean) untuk menjaga konsistensi data dimana data itu sudah bisa terbaca
#
# ![Screenshot 2026-04-22 084113.png](data:image/png;base64,...)

# %% [markdown]
# ##3 Pembagian Data
# 80% data training
# 20% data testing
#
# Dengan hasil google collab
# Accuracy: 0.92
# Precision: 0.91
# Recall: 0.89
# F1 Score: 0.90
# Confusion Matrix:
# [185  15]
# [ 20 180]
#
# Jadi pada:
# TN = 185
# FP = 15
# FN = 20
# TP = 180
#
# ![image.png](attachment:image.png)
#
# Hasil menunjukkan bahwa model KNN masih memiliki performa yang rendah dalam mengklasifikasikan data kesuburan tanah. Hal ini terlihat dari nilai accuracy yang hanya mencapai sekitar setengah dari total data, serta nilai precision dan recall yang menunjukkan bahwa banyak terjadi kesalahan prediksi baik pada kelas Subur maupun Tidak Subur.
# Tingginya nilai kesalahan (False Positive dan False Negative) mengindikasikan bahwa model belum mampu membedakan kedua kelas dengan baik. Hal ini kemungkinan disebabkan oleh pemilihan parameter K yang belum optimal, serta proses preprocessing data yang belum maksimal.
